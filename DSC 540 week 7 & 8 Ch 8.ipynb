# %%
##Imports
import pandas as pd
import numpy as np

# %%
##View Directory
import os 
print(os)
# Out:
# <module 'os' from 'C:\\Users\\14029\\anaconda3\\lib\\os.py'>

# %%
##Load data and view 
na_values = [""," ",None,"Missing","NA"]
df=pd.read_csv("candyhierarchy2017.csv",encoding='latin-1',na_values=na_values)
df.head()
# Out:
#    Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 0     90258773            NaN        NaN     NaN         NaN
# 1     90272821             No       Male      44        USA
# 2     90272829            NaN       Male      49         USA
# 3     90272840             No       Male      40          us
# 4     90272841             No       Male      23         usa
#
#   Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 0                              NaN                NaN
# 1                               NM                MEH
# 2                         Virginia                NaN
# 3                               or                MEH
# 4                         exton pa                JOY
#
#   Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# 3                                            DESPAIR
# 4                                            DESPAIR
#
#   Q6 | Any full-sized candy bar Q6 | Black Jacks  ... Q8: DESPAIR OTHER  \
# 0                           NaN              NaN  ...               NaN
# 1                           JOY              MEH  ...               NaN
# 2                           NaN              NaN  ...               NaN
# 3                           JOY              MEH  ...               NaN
# 4                           JOY          DESPAIR  ...               NaN
#
#                                   Q9: OTHER COMMENTS      Q10: DRESS  \
# 0                                                NaN             NaN
# 1  Bottom line is Twix is really the only candy w...  White and gold
# 2                                                NaN             NaN
# 3                             Raisins can go to hell  White and gold
# 4                                                NaN  White and gold
#
#   Unnamed: 113 Q11: DAY Q12: MEDIA [Daily Dish] Q12: MEDIA [Science]  \
# 0          NaN      NaN                     NaN                  NaN
# 1          NaN   Sunday                     NaN                  1.0
# 2          NaN      NaN                     NaN                  NaN
# 3          NaN   Sunday                     NaN                  1.0
# 4          NaN   Friday                     NaN                  1.0
#
#   Q12: MEDIA [ESPN] Q12: MEDIA [Yahoo] Click Coordinates (x, y)
# 0               NaN                NaN                      NaN
# 1               NaN                NaN                 (84, 25)
# 2               NaN                NaN                      NaN
# 3               NaN                NaN                 (75, 23)
# 4               NaN                NaN                 (70, 10)
#
# [5 rows x 120 columns]

# %%
##Prep for hierarchical view and data reshaping

# %%
candy_names = {x:x.split('Q6 | ')[1] for x in df.columns if x.startswith('Q6 | ')}

# %%
##Prep for hierarchical view
df.rename(columns=candy_names,inplace=True)
df.reset_index(inplace=True)
##df.set_index(list(candy_names.values()),inplace=True)
df.head()
# Out:
#    level_0  index  Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 0        0      0     90258773            NaN        NaN     NaN         NaN
# 1        1      1     90272821             No       Male      44        USA
# 2        2      2     90272829            NaN       Male      49         USA
# 3        3      3     90272840             No       Male      40          us
# 4        4      4     90272841             No       Male      23         usa
#
#   Q5: STATE, PROVINCE, COUNTY, ETC 100 Grand Bar  \
# 0                              NaN           NaN
# 1                               NM           MEH
# 2                         Virginia           NaN
# 3                               or           MEH
# 4                         exton pa           JOY
#
#   Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# 3                                            DESPAIR
# 4                                            DESPAIR
#
#    ... Q8: DESPAIR OTHER                                 Q9: OTHER COMMENTS  \
# 0  ...               NaN                                                NaN
# 1  ...               NaN  Bottom line is Twix is really the only candy w...
# 2  ...               NaN                                                NaN
# 3  ...               NaN                             Raisins can go to hell
# 4  ...               NaN                                                NaN
#
#        Q10: DRESS Unnamed: 113 Q11: DAY Q12: MEDIA [Daily Dish]  \
# 0             NaN          NaN      NaN                     NaN
# 1  White and gold          NaN   Sunday                     NaN
# 2             NaN          NaN      NaN                     NaN
# 3  White and gold          NaN   Sunday                     NaN
# 4  White and gold          NaN   Friday                     NaN
#
#   Q12: MEDIA [Science] Q12: MEDIA [ESPN] Q12: MEDIA [Yahoo]  \
# 0                  NaN               NaN                NaN
# 1                  1.0               NaN                NaN
# 2                  NaN               NaN                NaN
# 3                  1.0               NaN                NaN
# 4                  1.0               NaN                NaN
#
#   Click Coordinates (x, y)
# 0                      NaN
# 1                 (84, 25)
# 2                      NaN
# 3                 (75, 23)
# 4                 (70, 10)
#
# [5 rows x 122 columns]

# %%
##Insert Candy Column
new_index = pd.Index(list(candy_names.values()),name='Candy')
new_df = df.reindex(columns=new_index)
new_df.head()
# Out:
# Candy 100 Grand Bar  \
# 0               NaN
# 1               MEH
# 2               NaN
# 3               MEH
# 4               JOY
#
# Candy Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 0                                                    NaN
# 1                                                DESPAIR
# 2                                                    NaN
# 3                                                DESPAIR
# 4                                                DESPAIR
#
# Candy Any full-sized candy bar Black Jacks Bonkers (the candy)  \
# 0                          NaN         NaN                 NaN
# 1                          JOY         MEH             DESPAIR
# 2                          NaN         NaN                 NaN
# 3                          JOY         MEH                 MEH
# 4                          JOY     DESPAIR                 MEH
#
# Candy Bonkers (the board game) Bottle Caps Box'o'Raisins Broken glow stick  \
# 0                          NaN         NaN           NaN               NaN
# 1                      DESPAIR     DESPAIR       DESPAIR           DESPAIR
# 2                          NaN         NaN           NaN               NaN
# 3                      DESPAIR         MEH       DESPAIR           DESPAIR
# 4                      DESPAIR         MEH       DESPAIR           DESPAIR
#
# Candy Butterfinger  ... Three Musketeers Tolberone something or other  \
# 0              NaN  ...              NaN                          NaN
# 1          DESPAIR  ...              JOY                          JOY
# 2              NaN  ...              NaN                          NaN
# 3              MEH  ...          DESPAIR                          JOY
# 4              MEH  ...              JOY                          JOY
#
# Candy Trail Mix Twix  \
# 0           NaN  NaN
# 1       DESPAIR  JOY
# 2           NaN  NaN
# 3           MEH  JOY
# 4       DESPAIR  JOY
#
# Candy Vials of pure high fructose corn syrup, for main-lining into your vein  \
# 0                                                    NaN
# 1                                                DESPAIR
# 2                                                    NaN
# 3                                                DESPAIR
# 4                                                    MEH
#
# Candy  Vicodin Whatchamacallit Bars White Bread Whole Wheat anything  \
# 0          NaN                  NaN         NaN                  NaN
# 1      DESPAIR              DESPAIR     DESPAIR              DESPAIR
# 2          NaN                  NaN         NaN                  NaN
# 3          JOY                  JOY     DESPAIR              DESPAIR
# 4          JOY                  JOY     DESPAIR              DESPAIR
#
# Candy York Peppermint Patties
# 0                         NaN
# 1                     DESPAIR
# 2                         NaN
# 3                     DESPAIR
# 4                         JOY
#
# [5 rows x 103 columns]

# %%
##remove columns to view specific info
ldata = new_df.stack().reset_index().rename(columns={0: 'Candy_Approval'})
ldata[:10]
# Out:
#    level_0                                              Candy Candy_Approval
# 0        1                                      100 Grand Bar            MEH
# 1        1  Anonymous brown globs that come in black and o...        DESPAIR
# 2        1                           Any full-sized candy bar            JOY
# 3        1                                        Black Jacks            MEH
# 4        1                                Bonkers (the candy)        DESPAIR
# 5        1                           Bonkers (the board game)        DESPAIR
# 6        1                                        Bottle Caps        DESPAIR
# 7        1                                      Box'o'Raisins        DESPAIR
# 8        1                                  Broken glow stick        DESPAIR
# 9        1                                       Butterfinger        DESPAIR
